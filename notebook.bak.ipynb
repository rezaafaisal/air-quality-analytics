# %% [markdown]
# # Proyek Analisis Data: Air Quality
# - Nama: Reza Faisal
# - Email: rezha.faizal567@gmail.com
# - Id Dicoding: rezaafaisal

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - pertanyaan 1
# - pertanyaan 2

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data
# Pada tahap ini data kualitas udara dari setiap stasiun akan di load dan dijadikan dataframe

# %%
# list files
sources = [
    'PRSA_Data_Aotizhongxin_20130301-20170228.csv',
    'PRSA_Data_Changping_20130301-20170228.csv',
    'PRSA_Data_Dingling_20130301-20170228.csv',
    'PRSA_Data_Dongsi_20130301-20170228.csv',
    'PRSA_Data_Guanyuan_20130301-20170228.csv',
    'PRSA_Data_Gucheng_20130301-20170228.csv',
    'PRSA_Data_Huairou_20130301-20170228.csv',
    'PRSA_Data_Nongzhanguan_20130301-20170228.csv',
    'PRSA_Data_Shunyi_20130301-20170228.csv',
    'PRSA_Data_Tiantan_20130301-20170228.csv',
    'PRSA_Data_Wanliu_20130301-20170228.csv',
    'PRSA_Data_Wanshouxigong_20130301-20170228.csv'
]

# list stations
stations = [source.split('_')[2].lower() for source in sources]

# %%
# make dataframe variables
dfs = {}
for i, source in enumerate(sources):
    dfs[stations[i]] = pd.read_csv('data/'+source)
    
aotizhongxin_df = dfs['aotizhongxin']
changping_df = dfs['changping']
dingling_df = dfs['dingling']
dongsi_df = dfs['dongsi']
guanyuan_df = dfs['guanyuan']
gucheng_df = dfs['gucheng']
huairou_df = dfs['huairou'] 
nongzhanguan_df = dfs['nongzhanguan']
shunyi_df = dfs['shunyi']
tiantan_df = dfs['tiantan']
wanliu_df = dfs['wanliu']
wanshouxigong_df = dfs['wanshouxigong']

# %% [markdown]
# ### Assessing Data

# %%
# membuat function untuk asesing data
def assessing(df, name):
    # melihat informasi tipe data
    df.info()
    # melihat ukuran data
    print('\nShape '+name+':\n', df.shape)
    # cek missing value
    print('\nMissing Value '+name+':\n', df.isna().sum())
    # cek duplikasi
    print('\nDuplicate '+name+':', df.duplicated().sum())
    # describe dataframe
    print('\nDescribe '+name+':\n',df.describe())

# %% [markdown]
# #### Menilai data Aotizhongxin

# %%
assessing(aotizhongxin_df, 'Aotizhongxin')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Aotizhongxin:
# ...

# %% [markdown]
# #### Menilai data Changping

# %%
assessing(changping_df, 'Changpin')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Changpin:
# ...

# %% [markdown]
# #### Menilai Data Dingling

# %%
assessing(dingling_df, 'Dingling')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Dingling:
# ...

# %% [markdown]
# #### Menilai data Dongsi

# %%
assessing(dongsi_df, 'Dongsi')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Dongsi:
#  (35064, 18)
# ...

# %% [markdown]
# #### Menilai data Guanyuan

# %%
assessing(guanyuan_df, 'Guanyuan')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Guanyuan:
# ...

# %% [markdown]
# #### Menilai data Gucheng

# %%
assessing(gucheng_df, 'Gucheng')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Gucheng:
#  (35064, 18)
# ...

# %% [markdown]
# #### Menilai data Huairou

# %%
assessing(huairou_df, 'Huairou')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Huairou:
#  (35064, 18)
# ...

# %% [markdown]
# #### Menilai data Nongzhanguan

# %%
assessing(nongzhanguan_df, 'Nongzhanguan')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Nongzhanguan:
# ...

# %% [markdown]
# #### Menilai data Shunyi

# %%
assessing(shunyi_df, 'Shunyi')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Shunyi:
#  (35064, 18)
# ...

# %% [markdown]
# #### Menilai data Tiantan

# %%
assessing(tiantan_df, 'Tiantan')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Tiantan:
#  (35064, 18)
# ...

# %% [markdown]
# #### Menilai data Wanliu

# %%
assessing(wanliu_df, 'Wanliu')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Wanliu:
#  (35064, 18)
# ...

# %% [markdown]
# #### Menilai data Wanshouxigong

# %%
assessing(wanshouxigong_df, 'Wanshouxigong')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# Shape Wanshouxigong:
# ...

# %% [markdown]
# ### Cleaning Data

# %%
def cleaning(df):
    # menghilangkan missing value
    df.dropna(inplace=True)
    # mengubah setiap kolom tanggal dan waktu menjadi kolom datetime
    df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])
    return df

# %% [markdown]
# #### Membersihkan data Aotizhongxin

# %%
aotizhongxin_df = cleaning(aotizhongxin_df)

# %%
aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31815 entries, 0 to 35063
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        31815 non-null  int64
#  1   year      31815 non-null  int64
#  2   month     31815 non-null  int64
#  3   day       31815 non-null  int64
#  4   hour      31815 non-null  int64
#  5   PM2.5     31815 non-null  float64
#  6   PM10      31815 non-null  float64
#  7   SO2       31815 non-null  float64
#  8   NO2       31815 non-null  float64
#  9   CO        31815 non-null  float64
#  10  O3        31815 non-null  float64
#  11  TEMP      31815 non-null  float64
#  12  PRES      31815 non-null  float64
#  13  DEWP      31815 non-null  float64
#  14  RAIN      31815 non-null  float64
#  15  wd        31815 non-null  object
#  16  WSPM      31815 non-null  float64
#  17  station   31815 non-null  object
#  18  datetime  31815 non-null  datetime64[ns]
# ...

# %%
aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  31815.000000  31815.000000  31815.000000  31815.000000  31815.000000
# mean   17899.423857   2014.714914      6.401886     15.578564     11.624800
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9415.500000   2014.000000      3.000000      8.000000      6.000000
# 50%    18093.000000   2015.000000      6.000000     15.000000     12.000000
# 75%    26590.500000   2016.000000      9.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# std    10058.429849      1.162536      3.416847      8.794954      6.926874
#
#              PM2.5          PM10           SO2           NO2            CO  \
# count  31815.00000  31815.000000  31815.000000  31815.000000  31815.000000
# mean      81.86363    109.120685     17.167205     58.976332   1256.574729
# ...

# %% [markdown]
# #### Membersihkan data Changpin

# %%
changping_df = cleaning(changping_df)
print('Missing value :', changping_df.isna().sum())
changping_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  32681.000000  32681.000000  32681.000000  32681.000000  32681.000000
# mean   17876.569658   2014.703130      6.507481     15.715156     11.506992
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9384.000000   2014.000000      3.000000      8.000000      6.000000
# 50%    17910.000000   2015.000000      7.000000     16.000000     11.000000
# 75%    26546.000000   2016.000000     10.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Dingling

# %%
dingling_df = cleaning(dingling_df)
print('Missing value :', dingling_df.isna().sum())
dingling_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  31306.000000  31306.000000  31306.000000  31306.000000  31306.000000
# mean   17951.165719   2014.718297      6.422603     15.881237     11.504248
# min        3.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9888.250000   2014.000000      3.000000      8.000000      6.000000
# 50%    18100.500000   2015.000000      6.000000     16.000000     11.000000
# 75%    26268.750000   2016.000000      9.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Dongsi

# %%
dongsi_df = cleaning(dongsi_df)
print('Missing value :', dongsi_df.isna().sum())
dongsi_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  30338.000000  30338.000000  30338.000000  30338.000000  30338.000000
# mean   18808.565759   2014.807832      6.530160     15.650109     11.500363
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%    11435.250000   2014.000000      4.000000      8.000000      5.000000
# 50%    19161.500000   2015.000000      7.000000     16.000000     11.000000
# 75%    26926.750000   2016.000000     10.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Guanyuan

# %%
guanyuan_df = cleaning(guanyuan_df)
print('Missing value :', guanyuan_df.isna().sum())
guanyuan_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  32263.000000  32263.000000  32263.000000  32263.000000  32263.000000
# mean   18055.294300   2014.731519      6.411555     15.718780     11.548368
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9790.500000   2014.000000      3.000000      8.000000      6.000000
# 50%    18323.000000   2015.000000      6.000000     16.000000     12.000000
# 75%    26555.000000   2016.000000      9.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Gucheng

# %%
gucheng_df = cleaning(gucheng_df)
print('Missing value :', gucheng_df.isna().sum())
gucheng_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  32504.000000  32504.000000  32504.000000  32504.000000  32504.000000
# mean   17939.595619   2014.715174      6.449360     15.716035     11.530396
# min       21.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9477.750000   2014.000000      3.000000      8.000000      6.000000
# 50%    18119.500000   2015.000000      6.000000     16.000000     12.000000
# 75%    26617.250000   2016.000000      9.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Mebersihkan data Huairo

# %%
huairou_df = cleaning(huairou_df)
print('Missing value :', huairou_df.isna().sum())
huairou_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  31708.000000  31708.000000  31708.000000  31708.000000  31708.000000
# mean   17854.999653   2014.697931      6.541504     15.668633     11.661063
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9310.750000   2014.000000      3.000000      8.000000      6.000000
# 50%    17872.500000   2015.000000      7.000000     16.000000     12.000000
# 75%    26456.250000   2016.000000     10.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Nongzhanguan

# %%
nongzhanguan_df = cleaning(nongzhanguan_df)
print('Missing value :', nongzhanguan_df.isna().sum())
nongzhanguan_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  33114.000000  33114.000000  33114.000000  33114.000000  33114.000000
# mean   17651.646554   2014.681373      6.461799     15.685420     11.519176
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9071.250000   2014.000000      3.000000      8.000000      6.000000
# 50%    17735.500000   2015.000000      6.000000     16.000000     11.000000
# 75%    26323.750000   2016.000000      9.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Shunyi

# %%
shunyi_df = cleaning(shunyi_df)
print('Missing value :', shunyi_df.isna().sum())
shunyi_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  30194.000000  30194.000000  30194.000000  30194.000000  30194.000000
# mean   17586.308902   2014.672286      6.477214     15.797244     11.750447
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9084.250000   2014.000000      3.000000      8.000000      6.000000
# 50%    17607.500000   2015.000000      6.000000     16.000000     12.000000
# 75%    25872.750000   2016.000000     10.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Tiantan

# %%
tiantan_df = cleaning(tiantan_df)
print('Missing value :', tiantan_df.isna().sum())
tiantan_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  32843.000000  32843.000000  32843.000000  32843.000000  32843.000000
# mean   17807.867217   2014.693481      6.533447     15.579697     11.527449
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9026.500000   2014.000000      4.000000      8.000000      6.000000
# 50%    18025.000000   2015.000000      7.000000     15.000000     12.000000
# 75%    26551.500000   2016.000000     10.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Wanliu

# %%
wanliu_df = cleaning(wanliu_df)
print('Missing value :', wanliu_df.isna().sum())
wanliu_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  30634.000000  30634.000000  30634.000000  30634.000000  30634.000000
# mean   18281.563067   2014.752954      6.459587     15.853627     11.716687
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%    10147.250000   2014.000000      3.000000      8.000000      6.000000
# 50%    18933.500000   2015.000000      7.000000     16.000000     12.000000
# 75%    27013.750000   2016.000000      9.000000     24.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# #### Membersihkan data Wanshouxigong

# %%
wanshouxigong_df = cleaning(wanshouxigong_df)
print('Missing value :', wanshouxigong_df.isna().sum())
wanshouxigong_df.describe()
# Out:
# Missing value : No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
#                  No          year         month           day          hour  \
# count  32768.000000  32768.000000  32768.000000  32768.000000  32768.000000
# mean   17813.193787   2014.696228      6.504272     15.705750     11.530457
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     9401.750000   2014.000000      4.000000      8.000000      6.000000
# 50%    17925.500000   2015.000000      7.000000     16.000000     12.000000
# 75%    26452.250000   2016.000000     10.000000     23.000000     18.000000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Aotizhongxin

# %%
aotizhongxin_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   31815.000000  31815.000000  31815.000000  31815.000000  31815.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17899.423857   2014.714914      6.401886     15.578564     11.624800
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      9415.500000   2014.000000      3.000000      8.000000      6.000000
# 50%     18093.000000   2015.000000      6.000000     15.000000     12.000000
# 75%     26590.500000   2016.000000      9.000000     23.000000     18.000000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
# std     10058.429849      1.162536      3.416847      8.794954      6.926874
#
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - conclution pertanyaan 2
